# %%
import pandas as pd

# Source: https://archive.ics.uci.edu/dataset/352/online+retail

df = pd.read_excel("../data/raw/Online Retail.xlsx")
df.to_csv("../data/raw/online_retail_data.csv", index=False)
